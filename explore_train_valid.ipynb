# %% [markdown]
# # Explore train and validation CSVs
#
# ## Setup

# %%
import pandas as pd
import numpy as np
import os

# %%
DIR = 'CheXpert-v1.0-small'

# %% [markdown]
# ## Load

# %%
valid = pd.read_csv(os.path.join(DIR, 'valid.csv'))

# %%
train = pd.read_csv(os.path.join(DIR, 'valid.csv'), nrows=100)

# %% [markdown]
# ## Explore

# %% [markdown]
# Columns are identical between train and validation, so focus on `valid`.

# %%
np.array_equal(train.columns, valid.columns)
# Out:
# True

# %%
valid.columns
# Out:
# Index(['Path', 'Sex', 'Age', 'Frontal/Lateral', 'AP/PA', 'No Finding',
#        'Enlarged Cardiomediastinum', 'Cardiomegaly', 'Lung Opacity',
#        'Lung Lesion', 'Edema', 'Consolidation', 'Pneumonia', 'Atelectasis',
#        'Pneumothorax', 'Pleural Effusion', 'Pleural Other', 'Fracture',
#        'Support Devices'],
#       dtype='object')

# %%
valid.describe()
# Out:
#               Age  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# count  234.000000  234.000000                  234.000000    234.000000
# mean    60.790598    0.162393                    0.465812      0.290598
# std     18.554032    0.369602                    0.499899      0.455012
# min     18.000000    0.000000                    0.000000      0.000000
# 25%     48.250000    0.000000                    0.000000      0.000000
# 50%     62.500000    0.000000                    0.000000      0.000000
# 75%     75.000000    0.000000                    1.000000      1.000000
# max     90.000000    1.000000                    1.000000      1.000000
#
#        Lung Opacity  Lung Lesion       Edema  Consolidation   Pneumonia  \
# count    234.000000   234.000000  234.000000     234.000000  234.000000
# mean       0.538462     0.004274    0.192308       0.141026    0.034188
# std        0.499587     0.065372    0.394958       0.348794    0.182101
# ...

# %%
train.describe()
# Out:
#               Age  No Finding  Enlarged Cardiomediastinum  Cardiomegaly  \
# count  100.000000  100.000000                  100.000000     100.00000
# mean    57.810000    0.260000                    0.300000       0.21000
# std     19.347276    0.440844                    0.460566       0.40936
# min     18.000000    0.000000                    0.000000       0.00000
# 25%     47.000000    0.000000                    0.000000       0.00000
# 50%     59.000000    0.000000                    0.000000       0.00000
# 75%     71.250000    1.000000                    1.000000       0.00000
# max     90.000000    1.000000                    1.000000       1.00000
#
#        Lung Opacity  Lung Lesion       Edema  Consolidation   Pneumonia  \
# count        100.00        100.0  100.000000     100.000000  100.000000
# mean           0.45          0.0    0.170000       0.070000    0.040000
# std            0.50          0.0    0.377525       0.256432    0.196946
# ...
